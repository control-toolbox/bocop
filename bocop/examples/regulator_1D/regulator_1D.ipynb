# %%
import bocop
# solve (build and run) problem in local folder
bocop.solve()
# Out:
# interactive(children=(IntSlider(value=14, continuous_update=False, description='iteration', max=14), Output())…
# Done
# Loading solution:  /home/martinon/bocop/bocop3/bocop/examples/regulator_1D/problem.sol
